# %%
# !ls
# Out:
# drive  sample_data

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/GraduationProject/
# Out:
# /content/drive/MyDrive/GraduationProject

# %%
# !npm i -g @openai/codex
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦
# added 2 packages in 3s
# ⠦

# %%
# !codex
# Out:
# [>7u]10;?\
